# %% [markdown]
# <a href="https://colab.research.google.com/github/gpensabem/Learnings/blob/main/Exercicios_3_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn

# %%
from sklearn.datasets import load_wine
from sklearn.feature_selection import SelectKBest
#no caso de regressão precisa importar o f_regression
from sklearn.feature_selection import f_classif

# %%
wine = load_wine()

# %%
X = wine.data
y = wine.target

target_names = wine.target_names
feature_names = wine.feature_names

# %%
X
# Out:
# array([[1.423e+01, 1.710e+00, 2.430e+00, ..., 1.040e+00, 3.920e+00,
#         1.065e+03],
#        [1.320e+01, 1.780e+00, 2.140e+00, ..., 1.050e+00, 3.400e+00,
#         1.050e+03],
#        [1.316e+01, 2.360e+00, 2.670e+00, ..., 1.030e+00, 3.170e+00,
#         1.185e+03],
#        ...,
#        [1.327e+01, 4.280e+00, 2.260e+00, ..., 5.900e-01, 1.560e+00,
#         8.350e+02],
#        [1.317e+01, 2.590e+00, 2.370e+00, ..., 6.000e-01, 1.620e+00,
#         8.400e+02],
#        [1.413e+01, 4.100e+00, 2.740e+00, ..., 6.100e-01, 1.600e+00,
#         5.600e+02]])

# %%
selector = SelectKBest(f_classif, k=3)
X_new=selector.fit_transform(X,y)
X_new.shape
# Out:
# (178, 3)

# %%
from sklearn import decomposition
from sklearn import datasets

# %%
pca = decomposition.PCA(n_components=2)
pca.fit(X)
X_pca = pca.transform(X)
X_pca
# Out:
# array([[ 3.18562979e+02,  2.14921307e+01],
#        [ 3.03097420e+02, -5.36471768e+00],
#        [ 4.38061133e+02, -6.53730945e+00],
#        [ 7.33240139e+02,  1.92729032e-01],
#        [-1.15714285e+01,  1.84899946e+01],
#        [ 7.03231192e+02, -3.32158674e-01],
#        [ 5.42971581e+02, -1.35189666e+01],
#        [ 5.48401860e+02,  1.14494324e+01],
#        [ 2.98036863e+02, -8.18015784e+00],
#        [ 2.98049553e+02, -7.10154294e+00],
#        [ 7.63079712e+02, -8.33431723e+00],
#        [ 5.32943228e+02, -1.42876338e+01],
#        [ 5.72834410e+02, -2.10050143e+01],
#        [ 4.02925358e+02, -1.61026352e+01],
#        [ 8.00053394e+02, -1.21184472e+01],
#        [ 5.63245578e+02,  2.21482866e+00],
#        [ 5.33379651e+02,  1.08048022e+01],
#        [ 3.83317591e+02,  8.47741982e+00],
#        [ 9.33118387e+02, -8.35447844e+00],
#        [ 9.84031775e+01,  1.43926594e+01],
#        [ 3.35935940e+01,  2.55679565e+01],
#        [ 2.31464375e+01,  1.81747309e+00],
# ...

# %%
import matplotlib.pyplot as plt
scatter=plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, alpha=.8, lw=2)

plt.xlabel('Componente 1 expressa '+ str("{:.2f}".format(100*pca.explained_variance_ratio_[0])) + '% de variabilidade')
plt.ylabel('Componente 2 expressa ' + str("{:.2f}".format(100*pca.explained_variance_ratio_[1])) + '% de variabilidade')
plt.legend(scatter.legend_elements()[0],target_names, loc="lower right", title="Classes")
plt.title('PCA da base de dados WINE')
# Out:
# Text(0.5, 1.0, 'PCA da base de dados WINE')

# %%
# Out:
# sklearn.utils._bunch.Bunch

# %%
import pandas as pd

wine_df = pd.DataFrame(wine.data, columns=wine.feature_names)
wine_df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
import seaborn as sns

correlacoes = wine_df.corr()
sns.heatmap(correlacoes, annot=True)
# Out:
# <Axes: >
